# %%
import pandas_datareader.data as web

# %%
import datetime

# %%
start = datetime.datetime(2015,1,1)
end = datetime.datetime(2017,1,1)

# %%
facebook = web.DataReader('FB', 'yahoo', start, end)

# %%
facebook.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2021-07-09  350.709991  345.269989  345.320007  350.420013  13018700
# 2021-07-12  354.190002  349.640015  351.230011  353.160004  10018600
# 2021-07-13  358.489990  348.799988  351.500000  352.089996  11456000
# 2021-07-14  355.200012  346.730011  354.559998  347.630005  13894200
# 2021-07-15  349.230011  340.220001  349.230011  344.459991  14781600
#
#              Adj Close
# Date
# 2021-07-09  350.420013
# 2021-07-12  353.160004
# 2021-07-13  352.089996
# 2021-07-14  347.630005
# 2021-07-15  344.459991

# %%
import quandl

# %%
mydata = quandl.get('EIA/PET_RWTC_D')

# %%
mydata.head()
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mydata.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
real_estate = quandl.get('ZILLOW/C9_ZRIFAH')

# %%
real_estate.head()
# Out:
#             Value
# Date
# 2010-11-30  1.500
# 2010-12-31  1.496
# 2011-01-31  1.490
# 2011-02-28  1.484
# 2011-03-31  1.478

# %%
apple = quandl.get('WIKI/AAPL')

# %%
apple.tail()
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2018-03-21  175.04  175.09  171.26  171.270  35247358.0          0.0
# 2018-03-22  170.00  172.68  168.60  168.845  41051076.0          0.0
# 2018-03-23  168.39  169.92  164.94  164.940  40248954.0          0.0
# 2018-03-26  168.07  173.10  166.44  172.770  36272617.0          0.0
# 2018-03-27  173.68  175.15  166.92  168.340  38962839.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2018-03-21          1.0     175.04     175.09    171.26     171.270
# 2018-03-22          1.0     170.00     172.68    168.60     168.845
# 2018-03-23          1.0     168.39     169.92    164.94     164.940
# 2018-03-26          1.0     168.07     173.10    166.44     172.770
# 2018-03-27          1.0     173.68     175.15    166.92     168.340
#
#             Adj. Volume
# Date
# 2018-03-21   35247358.0
# 2018-03-22   41051076.0
# 2018-03-23   40248954.0
# ...

# %%
FB = quandl.get('WIKI/FB')
FB.head()
# Out:
#              Open   High    Low    Close       Volume  Ex-Dividend  \
# Date
# 2012-05-18  42.05  45.00  38.00  38.2318  573576400.0          0.0
# 2012-05-21  36.53  36.66  33.00  34.0300  168192700.0          0.0
# 2012-05-22  32.61  33.59  30.94  31.0000  101786600.0          0.0
# 2012-05-23  31.37  32.50  31.36  32.0000   73600000.0          0.0
# 2012-05-24  32.95  33.21  31.77  33.0300   50237200.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2012-05-18          1.0      42.05      45.00     38.00     38.2318
# 2012-05-21          1.0      36.53      36.66     33.00     34.0300
# 2012-05-22          1.0      32.61      33.59     30.94     31.0000
# 2012-05-23          1.0      31.37      32.50     31.36     32.0000
# 2012-05-24          1.0      32.95      33.21     31.77     33.0300
#
#             Adj. Volume
# Date
# 2012-05-18  573576400.0
# 2012-05-21  168192700.0
# 2012-05-22  101786600.0
# 2012-05-23   73600000.0
# ...

# %%
# get just the first column
AMZN = quandl.get('WIKI/AMZN.2')
AMZN.head()
# Out:
#              High
# Date
# 1997-05-16  23.75
# 1997-05-19  21.25
# 1997-05-20  21.00
# 1997-05-21  19.75
# 1997-05-22  17.38

# %%
AMZN.tail()
# Out:
#                High
# Date
# 2018-03-21  1590.00
# 2018-03-22  1573.85
# 2018-03-23  1549.02
# 2018-03-26  1556.99
# 2018-03-27  1575.96

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from datetime import datetime

# %%
my_year = 2017
my_month = 1
my_day = 2
my_hour = 13
my_minute = 30
my_second = 15

# %%
my_date = datetime(my_year, my_month, my_day)
my_date
# Out:
# datetime.datetime(2017, 1, 2, 0, 0)

# %%
my_datetime = datetime(my_year, my_month, my_day, my_hour, my_minute)
my_datetime
# Out:
# datetime.datetime(2017, 1, 2, 13, 30)

# %%
my_datetime.day
# Out:
# 2

# %%
my_datetime.month
# Out:
# 1

# %%
first_two = [datetime(2016,1,1), datetime(2016,1,2)]

# %%
type(first_two)
# Out:
# list

# %%
dt_ind = pd.DatetimeIndex(first_two)

# %%
dt_ind
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02'], dtype='datetime64[ns]', freq=None)

# %%
data = np.random.randn(2,2)
data
# Out:
# array([[-0.12770415, -1.1237794 ],
#        [ 0.01940663,  1.87560642]])

# %%
cols = ['a', 'b']

# %%
df = pd.DataFrame(data, dt_ind, cols)
df
# Out:
#                    a         b
# 2016-01-01 -0.127704 -1.123779
# 2016-01-02  0.019407  1.875606

# %%
df.index.argmax()
# Out:
# 1

# %%
df.index.max()
# Out:
# Timestamp('2016-01-02 00:00:00')

# %%
df.index.argmin()
# Out:
# 0

# %%
df.index.min()
# Out:
# Timestamp('2016-01-01 00:00:00')

# %%
from tabula import read_pdf

# %%
import pandas as pd
df = read_pdf('/Users/utsav/Downloads/Kotak_2021-22.pdf', pages='all', pandas_options={'header':None})

# %%
len(df)
# Out:
# 17

# %%
df[14]
# Out:
#                                                     0                   1  \
# 0   10-Mar-22 Recd:IMPS/206915809066/Mr. Utsav /KK...   IMPS-206915684792
# 1     10-Mar-22 UPI/MANOJ POKADE/206911883815/livpure    UPI-206933851070
# 2                                             warrant                 NaN
# 3            10-Mar-22 UPI/GOOGLEPAY/206996377479/UPI    UPI-206933866394
# 4      11-Mar-22 UPI/SHREE GOKUL DAI/207022195216/UPI    UPI-207042413305
# 5         11-Mar-22 NACH-ECS-CR-COAL INDIA LTD-848749   NACHDB11032200093
# 6                                                 NaN                 473
# 7      12-Mar-22 UPI/CHITRAPANDI IYY/207139683621/UPI    UPI-207156036987
# 8      12-Mar-22 UPI/SHREE GOKUL DAI/207139818161/UPI    UPI-207156116668
# 9               12-Mar-22 ATW/9032/+Hill Road, Bandra        207112755411
# 10                             WestMumbai120322/17:48                 NaN
# 11              12-Mar-22 UPI/SWIGGY/207154902649/UPI    UPI-207167202621
# ...

# %%
ndf = pd.concat(df)

# %%
ndf.head()
# Out:
#            0                                                 1  \
# 0        NaN                      Statement of Banking Account
# 1       Date                                         Narration
# 2  01-Apr-21                                PENING BALANCE ...
# 3  01-Apr-21  TL/9032/900005/+CHINCHOLIBANDAR\rALA010421/12:14
# 4  01-Apr-21  B SENT TO Utsa 10062354578 IMPS Ref\r09112528453
#
#                    2                3             4             5        6   7
# 0                NaN              NaN           NaN           NaN      NaN NaN
# 1        Chq/Ref No.  Withdrawal (Dr)  Deposit (Cr)           NaN  Balance NaN
# 2                NaN              NaN      8,087.87  8,087.87 (Cr      NaN NaN
# 3       109102457686         1,000.00           NaN  7,087.87 (Cr      NaN NaN
# 4  IMPS-109112528369         2,000.00           NaN  5,087.87 (Cr      NaN NaN

# %%
ndf.columns = ['Date', 'Narration', 'Chq', 'Withdrawal', 'Deposit','temp','Balance','tte']

# %%
ndf.head()
# Out:
#         Date                                         Narration  \
# 0        NaN                      Statement of Banking Account
# 1       Date                                         Narration
# 2  01-Apr-21                                PENING BALANCE ...
# 3  01-Apr-21  TL/9032/900005/+CHINCHOLIBANDAR\rALA010421/12:14
# 4  01-Apr-21  B SENT TO Utsa 10062354578 IMPS Ref\r09112528453
#
#                  Chq       Withdrawal       Deposit          temp  Balance  \
# 0                NaN              NaN           NaN           NaN      NaN
# 1        Chq/Ref No.  Withdrawal (Dr)  Deposit (Cr)           NaN  Balance
# 2                NaN              NaN      8,087.87  8,087.87 (Cr      NaN
# 3       109102457686         1,000.00           NaN  7,087.87 (Cr      NaN
# 4  IMPS-109112528369         2,000.00           NaN  5,087.87 (Cr      NaN
#
#    tte
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
pdf = ndf[['Date', 'Narration', 'Chq', 'Deposit']]
pdf
# Out:
#                                               Date  \
# 0                                              NaN
# 1                                             Date
# 2                                        01-Apr-21
# 3                                        01-Apr-21
# 4                                        01-Apr-21
# ..                                             ...
# 46  31-Mar-22 UPI/CHITRAPANDI IYY/209057301160/UPI
# 0                        CASA Interest Certificate
# 0                                   Account Number
# 1                                       8511657133
# 2                                            Total
#
#                                            Narration                Chq  \
# 0                       Statement of Banking Account                NaN
# 1                                          Narration        Chq/Ref No.
# 2                                 PENING BALANCE ...                NaN
# ...

# %%
pdf = pdf.dropna()

# %%
pdf.head()
# Out:
#         Date                                         Narration  \
# 0        NaN                      Statement of Banking Account
# 1       Date                                         Narration
# 2  01-Apr-21                                PENING BALANCE ...
# 3  01-Apr-21  TL/9032/900005/+CHINCHOLIBANDAR\rALA010421/12:14
# 4  01-Apr-21  B SENT TO Utsa 10062354578 IMPS Ref\r09112528453
#
#                  Chq       Deposit
# 0                NaN           NaN
# 1        Chq/Ref No.  Deposit (Cr)
# 2                NaN      8,087.87
# 3       109102457686           NaN
# 4  IMPS-109112528369           NaN

# %%
pdf[pdf['Narration'].str.contains('NACH')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-12315828d01a> in <module>
# ----> 1 pdf[pdf['Narration'].str.contains('NACH')]
#
# ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3012
#    3013         # Do we have a (boolean) 1d indexer?
# -> 3014         if com.is_bool_indexer(key):
#    3015             return self._getitem_bool_array(key)
#    3016
#
# ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     112                     # Don't raise on e.g. ["A", "B", np.nan], see
#     113                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 114                     raise ValueError(na_msg)
#     115                 return False
#     116             return True
#
# ...

# %%
pdf
# Out:
# Empty DataFrame
# Columns: [Date, Narration, Chq, Withdrawal, Deposit, temp, Balance, tte]
# Index: []

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/utsav/Downloads/dividend_2021_22.csv')

# %%
df.head()
# Out:
#          date    company     div  tds
# 0  2021.04.09       IOCL   780.0  NaN
# 1  2021.04.16  Britannia  1178.0  NaN
# 2  2021.05.19     Nestle    90.0  NaN
# 3  2021.05.20      Quess    70.0  NaN
# 4  2021.06.07  Britannia   237.5  NaN

# %%
df.query("company == 'ITC'")['div'].agg('sum')
# Out:
# 20889.0

# %%
20889+2322
# Out:
# 23211

# %%
df.sort_values(by='div', ascending=False)[:15]
# Out:
#           date company      div     tds
# 20  2021.08.13     ITC  10919.0     NaN
# 67  2022.03.04     ITC   9970.0  2322.0
# 59  2021.12.21     CIL   5719.0     NaN
# 56  2021.12.03    Ongc   4436.0     NaN
# 6   2021.06.25    Infy   3630.0     NaN
# 65  2022.03.04   nalco   3504.0     NaN
# 71  2022.03.11     CIL   3321.0  1292.0
# 58  2021.12.10   Nalco   2920.0     NaN
# 47  2021.11.10    INFY   2904.0     NaN
# 66  2022.03.04   IRCTC   2850.0     NaN
# 37  2021.09.23     CIL   2583.0     NaN
# 40  2021.09.30    ONGC   1722.0     NaN
# 70  2022.03.05    ONGC   1466.0   685.0
# 45  2021.10.25   NALCO   1460.0     NaN
# 44  2021.10.21   IRCTC   1425.0     NaN

# %%
df['com'] = df.company.str.lower()
df.head()
# Out:
#          date    company     div  tds        com
# 0  2021.04.09       IOCL   780.0  NaN       iocl
# 1  2021.04.16  Britannia  1178.0  NaN  britannia
# 2  2021.05.19     Nestle    90.0  NaN     nestle
# 3  2021.05.20      Quess    70.0  NaN      quess
# 4  2021.06.07  Britannia   237.5  NaN  britannia

# %%
df.groupby('com', as_index=False)[['div']].sum().sort_values('div', ascending=False)[:10]
# Out:
#           com      div
# 22        itc  20889.0
# 6         cil  11623.0
# 32      nalco   7884.0
# 34       ongc   7624.0
# 19       infy   6534.0
# 21      irctc   4275.0
# 20       iocl   3510.0
# 44    vedanta   2160.0
# 42        tcs   2160.0
# 4   britannia   1415.5

# %%
1292+11623
# Out:
# 12915

# %%
df['date'] = pd.to_datetime(df.date)

# %%
df.set_index('date', inplace=True)

# %%
df.resample('QS').sum()
# Out:
#                  div     tds
# date
# 2021-04-01   7370.50     0.0
# 2021-07-01  24332.81     0.0
# 2021-10-01  22670.10     0.0
# 2022-01-01  25460.00  4299.0

# %%
84057 - (7370 + 24332 + 22670)
# Out:
# 29685

# %%
84057 - 22670
# Out:
# 61387
